# %% [markdown]
# ## Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %% [markdown]
# Assuming you have collected data on n pairs of (time spent studying, exam score), you can calculate the Pearson correlation coefficient as follows:
#
# Calculate the mean of both variables:
#
# mean_time = (sum of all time spent studying) / n
#
# mean_score = (sum of all exam scores) / n
#
# Calculate the covariance between time spent studying and exam scores:
#
# covariance = (sum of [(time_i - mean_time) * (score_i - mean_score)]) / (n - 1)
#
# Calculate the standard deviation of both variables:
#
# std_time = sqrt((sum of [(time_i - mean_time)^2]) / (n - 1))
#
# std_score = sqrt((sum of [(score_i - mean_score)^2]) / (n - 1))
#
# Compute the Pearson correlation coefficient:
#
# r = covariance / (std_time * std_score)
#
# The resulting value of r will range between -1 and 1. A value of -1 indicates a perfect negative linear relationship between the two variables, while a value of 1 indicates a perfect positive linear relationship. A value of 0 indicates no linear relationship between the variables.
#
# Interpreting the result of the Pearson correlation coefficient in the context of the study, a positive value of r indicates that there is a positive linear relationship between the amount of time students spend studying for an exam and their final exam scores. In other words, as the amount of time spent studying increases, so does the final exam score. The magnitude of r indicates the strength of the relationship, with values closer to 1 indicating a stronger relationship. However, it's important to note that correlation does not imply causation and other factors could also be influencing the exam scores.

# %% [markdown]
# ## Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.

# %% [markdown]
# To calculate the Spearman's rank correlation between the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10, you need to first convert the data into ranks.
#
# Assuming you have collected data on n individuals, you can calculate the Spearman's rank correlation coefficient as follows:
#
# Rank the data for both variables from smallest to largest, assigning the smallest value a rank of 1, the second smallest a rank of 2, and so on.
#
# Calculate the difference between the ranks for each pair of individuals:
#
# d_i = rank_sleep_i - rank_satisfaction_i
#
# Calculate the Spearman's rank correlation coefficient using the formula:
#
# r_s = 1 - (6 * sum of (d_i^2) / (n * (n^2 - 1)))
#
# The resulting value of r_s will range between -1 and 1. A value of -1 indicates a perfect negative monotonic relationship between the two variables, while a value of 1 indicates a perfect positive monotonic relationship. A value of 0 indicates no monotonic relationship between the variables.
#
# Interpreting the result of the Spearman's rank correlation coefficient in the context of the study, a positive value of r_s indicates that there is a positive monotonic relationship between the amount of sleep individuals get each night and their overall job satisfaction level. In other words, as the amount of sleep increases, so does the job satisfaction level, but the relationship may not necessarily be linear. The magnitude of r_s indicates the strength of the monotonic relationship, with values closer to 1 indicating a stronger relationship.

# %% [markdown]
# ## Q3. Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.

# %% [markdown]
# Calculate the mean of both variables:
#
# mean_exercise = (sum of all hours of exercise) / n
#
# mean_BMI = (sum of all BMI) / n
#
# Calculate the covariance between hours of exercise and BMI:
#
# covariance = (sum of [(exercise_i - mean_exercise) * (BMI_i - mean_BMI)]) / (n - 1)
#
# Calculate the standard deviation of both variables:
#
# std_exercise = sqrt((sum of [(exercise_i - mean_exercise)^2]) / (n - 1))
#
# std_BMI = sqrt((sum of [(BMI_i - mean_BMI)^2]) / (n - 1))
#
# Compute the Pearson correlation coefficient:
#
# r = covariance / (std_exercise * std_BMI)
#
# To calculate the Spearman's rank correlation coefficient, you need to rank the data for both variables and then calculate the difference between the ranks for each pair of individuals as explained in the previous answer.
#
# Once you have both correlation coefficients, you can compare the results. If the relationship between the variables is linear, the Pearson correlation coefficient will be a more appropriate measure. If the relationship is not necessarily linear or there are outliers or non-normality in the data, then the Spearman's rank correlation coefficient may be more appropriate.
#
# In general, if the Pearson correlation coefficient and the Spearman's rank correlation coefficient are similar in magnitude and direction, it suggests a linear relationship between the variables. If the two coefficients are different in magnitude or direction, it suggests a non-linear or non-monotonic relationship between the variables.

# %% [markdown]
# ## Q4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between  these two variables.

# %% [markdown]
# Calculate the mean of both variables:
#
# mean_TV = (sum of all TV viewing hours) / 50
#
# mean_activity = (sum of all activity levels) / 50
#
# Calculate the covariance between TV viewing hours and activity levels:
#
# covariance = (sum of [(TV_i - mean_TV) * (activity_i - mean_activity)]) / 49
#
# Note that we use 49 instead of 50 in the denominator because we are estimating the population covariance from a sample.
#
# Calculate the standard deviation of both variables:
#
# std_TV = sqrt((sum of [(TV_i - mean_TV)^2]) / 49)
#
# std_activity = sqrt((sum of [(activity_i - mean_activity)^2]) / 49)
#
# Compute the Pearson correlation coefficient:
#
# r = covariance / (std_TV * std_activity)
#
# The resulting value of r will be a number between -1 and 1, where values closer to -1 or 1 indicate a stronger linear relationship between the two variables. A value of 0 would indicate no linear relationship.
#
# Interpreting the value of r in the context of the study, a positive value would suggest that as the number of hours individuals spend watching television per day increases, their level of physical activity tends to increase as well. A negative value would suggest the opposite, that as TV viewing time increases, physical activity tends to decrease. However, it is important to note that correlation does not imply causation, and other factors could be influencing the relationship between these variables.

# %% [markdown]
# ![Screenshot (5).png](attachment:5733f8a9-4977-4d0d-85cb-8c585cd475e7.png)

# %% [markdown]
# Based on the survey results provided, we can examine the relationship between age and preference for a particular brand of soft drink. From the given data, we can see that:
#
# Of the 6 respondents, 3 preferred Coke, 2 preferred Pepsi, and 1 preferred Mountain Dew.
# The youngest respondent, who was 19 years old, preferred Coke.
# The oldest respondent, who was 42 years old, preferred Pepsi.
# The other respondents, who were between 25 and 37 years old, had mixed preferences for Coke, Pepsi, and Mountain Dew.
# Based on this small sample, it is difficult to draw any definitive conclusions about the relationship between age and soft drink preference. However, it appears that there is no clear pattern or trend in soft drink preference based on age.
#
# To investigate this relationship further, a larger and more diverse sample would be needed. Additionally, more specific questions about soft drink preferences and consumption habits could provide more informative results.

# %% [markdown]
# ## Q6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %% [markdown]
# To calculate the Pearson correlation coefficient between the number of sales calls made per day and the number of sales made per week, we need to first calculate the mean and standard deviation of each variable, as well as their covariance. Let's assume that the data is normally distributed and there are no outliers in the data.
#
# Let x be the number of sales calls made per day, y be the number of sales made per week, and n be the sample size of 30.
#
# From the sample data, we can calculate:
#
# The sample mean of x, denoted by x̄, as the sum of all the x values divided by n.
# The sample mean of y, denoted by ȳ, as the sum of all the y values divided by n.
# The sample standard deviation of x, denoted by s_x, as the square root of the sum of the squared differences between each x value and the sample mean, divided by n-1.
# The sample standard deviation of y, denoted by s_y, as the square root of the sum of the squared differences between each y value and the sample mean, divided by n-1.
# The sample covariance between x and y, denoted by s_xy, as the sum of the product of the differences between each x value and the sample mean, and each y value and the sample mean, divided by n-1.
# Using these calculations, we can find:
#
# x̄ = (sum of x values)/n = (total number of sales calls)/(30) = (let's assume) 50
# ȳ = (sum of y values)/n = (total number of sales made)/(30) = (let's assume) 10
# s_x = sqrt[(sum of (x - x̄)^2)/(n-1)] = (let's assume) 5
# s_y = sqrt[(sum of (y - ȳ)^2)/(n-1)] = (let's assume) 2
# s_xy = (sum of [(x - x̄)(y - ȳ)])/(n-1) = (let's assume) 20
#
# Now we can use the formula for the Pearson correlation coefficient:
#
# r = s_xy / (s_x * s_y)
#
# Plugging in our calculated values, we get:
#
# r = 20 / (5 * 2) = 2
#
# The Pearson correlation coefficient between the number of sales calls made per day and the number of sales made per week is 2. Since the Pearson correlation coefficient ranges from -1 to 1, this value indicates a very strong positive correlation between the two variables. This means that as the number of sales calls made per day increases, the number of sales made per week also tends to increase. However, it is important to note that correlation does not imply causation, and there may be other factors that contribute to the number of sales made per week.
